# %%
# load in the necessary lib

# %%
import requests

# %%
from  bs4 import BeautifulSoup as br

# %%
# now load our page

# %%
r=requests.get('http://localhost:8888/notebooks/web.ipynb')

# %%
# convert to a beautiful soup objects

# %%
soup=br(r.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Jupyter Notebook
#   </title>
#   <link href="/static/base/images/favicon.ico?v=97c6417ed01bdc0ae3ef32ae4894fd03" id="favicon" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="/static/components/jquery-ui/themes/smoothness/jquery-ui.min.css?v=615f74f78b25617c6757fc3f641c10ac" rel="stylesheet" type="text/css"/>
#   <link href="/static/components/jquery-typeahead/dist/jquery.typeahead.min.css?v=3382267c9073d4d3ec590327e4415a51" rel="stylesheet" type="text/css"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="/static/style/style.min.css?v=66bc78bf9f6bdd18aeaba85f2ca2bed2" rel="stylesheet" type="text/css"/>
#   <link href="/static/auth/css/override.css?v=19ec59d2c4f1203c49fe47462028cd9a" rel="stylesheet" type="text/css"/>
#   <link href="/custom/custom.css" rel="stylesheet" type="text/css"/>
# ...

# %%
# now lets start scrapping

# %%
print(soup.find_all('a'))
# Out:
# [<a href="/tree" title="dashboard">
# <img alt="Jupyter Notebook" src="/static/base/images/logo.png?v=641991992878ee24c6f3826e81054a0f"/>
# </a>, <a href="https://jupyter-notebook.readthedocs.io/en/stable/public_server.html">
#             enable a password</a>, <a href="https://jupyter-notebook.readthedocs.io/en/stable/public_server.html">
#                 the documentation on how to enable a password</a>]

# %%
print(soup.find_all('body'))
# Out:
# [<body class="" dir="ltr">
# <noscript>
# <div id="noscript">
#       Jupyter Notebook requires JavaScript.<br/>
#       Please enable it to proceed.
#   </div>
# </noscript>
# <div id="header">
# <div class="container" id="header-container">
# <div class="nav navbar-brand" id="ipython_notebook"><a href="/tree" title="dashboard">
# <img alt="Jupyter Notebook" src="/static/base/images/logo.png?v=641991992878ee24c6f3826e81054a0f"/>
# </a></div>
# </div>
# <div class="header-bar"></div>
# </div>
# <div id="site">
# <div class="container" id="ipython-main-app">
# <div class="row">
# <div class="navbar col-sm-8">
# <div class="navbar-inner">
# <div class="container">
# <div class="center-nav">
# <form action="/login?next=%2Fnotebooks%2Fweb.ipynb" class="navbar-form pull-left" method="post">
# <input name="_xsrf" type="hidden" value="2|1e61139c|47ce1b562669570396e904b2c67c1e0b|1603284377"/>
# <label for="password_input"><strong>Password or token:</strong></label>
# ...

# %%
body=soup.find('body')

# %%
# print(body.get_text())

# noice
